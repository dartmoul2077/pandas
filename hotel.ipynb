# %%
import pandas as pd

# %%
bookings = pd.read_csv('https://stepik.org/media/attachments/lesson/360344/bookings.csv', sep = ';')

# %%
bookings = bookings.rename(columns = {'Hotel': 'hotel','Is Canceled': 'is_canceled', 'Lead Time': 'lead_time',\
                                'arrival full date': 'arrival_full_date', 'Arrival Date Year': 'arrival_date_year',\
                               'Arrival Date Month': 'arrival_date_month', 'Arrival Date Week Number': 'arrival_date_week_number',\
                               'Arrival Date Day of Month': 'arrival_date_day_of_month', 'Stays in Weekend nights': 'stays_in_weekend_nights',\
                               'Stays in week nights': 'stays_in_week_nights', 'stays total nights': 'stays_total_nights',\
                               'Adults': 'adults', 'Children': 'children', 'Babies': 'babies', 'Meal': 'meal', 'Country':'country',\
                               'Reserved Room Type': 'reserved_room_type', 'Assigned room type': 'assigned_room_type', 'customer type': 'customer_type',\
                               'Reservation Status': 'reservation_status', 'Reservation status_date': 'reservation_status_date'})

# %%
bookings[:7]
# Out:
#           hotel  is_canceled  lead_time arrival_full_date  arrival_date_year  \
# 0  Resort Hotel            0        342        2015-07-01               2015
# 1  Resort Hotel            0        737        2015-07-01               2015
# 2  Resort Hotel            0          7        2015-07-01               2015
# 3  Resort Hotel            0         13        2015-07-01               2015
# 4  Resort Hotel            0         14        2015-07-01               2015
# 5  Resort Hotel            0         14        2015-07-01               2015
# 6  Resort Hotel            0          0        2015-07-01               2015
#
#   arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0               July                        27                          1
# 1               July                        27                          1
# 2               July                        27                          1
# ...

# %%
bookings_head = bookings[:7]
bookings_head
# Out:
#           hotel  is_canceled  lead_time arrival_full_date  arrival_date_year  \
# 0  Resort Hotel            0        342        2015-07-01               2015
# 1  Resort Hotel            0        737        2015-07-01               2015
# 2  Resort Hotel            0          7        2015-07-01               2015
# 3  Resort Hotel            0         13        2015-07-01               2015
# 4  Resort Hotel            0         14        2015-07-01               2015
# 5  Resort Hotel            0         14        2015-07-01               2015
# 6  Resort Hotel            0          0        2015-07-01               2015
#
#   arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0               July                        27                          1
# 1               July                        27                          1
# 2               July                        27                          1
# ...

# %%
bookings.shape
# Out:
# (119390, 21)

# %%
bookings.dtypes.value_counts()
# Out:
# object     10
# int64      10
# float64     1
# dtype: int64

# %%
bookings
# Out:
#                hotel  is_canceled  lead_time arrival_full_date  \
# 0       Resort Hotel            0        342        2015-07-01
# 1       Resort Hotel            0        737        2015-07-01
# 2       Resort Hotel            0          7        2015-07-01
# 3       Resort Hotel            0         13        2015-07-01
# 4       Resort Hotel            0         14        2015-07-01
# ...              ...          ...        ...               ...
# 119385    City Hotel            0         23        2017-08-30
# 119386    City Hotel            0        102        2017-08-31
# 119387    City Hotel            0         34        2017-08-31
# 119388    City Hotel            0        109        2017-08-31
# 119389    City Hotel            0        205        2017-08-29
#
#         arrival_date_year arrival_date_month  arrival_date_week_number  \
# 0                    2015               July                        27
# ...

# %%
bookings.groupby(['is_canceled'],as_index = False).agg({'country':'sum'})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-35526c58c3e0> in <module>
# ----> 1 bookings.groupby(['is_canceled'],as_index = False).agg({'country':'sum'})
#
# D:\ANACONDA\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     943         func = maybe_mangle_lambdas(func)
#     944
# --> 945         result, how = aggregate(self, func, *args, **kwargs)
#     946         if how is None:
#     947             return result
#
# D:\ANACONDA\lib\site-packages\pandas\core\aggregation.py in aggregate(obj, arg, *args, **kwargs)
#     580     elif is_dict_like(arg):
#     581         arg = cast(AggFuncTypeDict, arg)
# --> 582         return agg_dict_like(obj, arg, _axis), True
#     583     elif is_list_like(arg):
#     584         # we require a list, but not an 'str'
#
# ...

# %%
bookings.groupby(['hotel'],as_index = False).agg({'stays_total_nights':'count'})
# Out:
#           hotel  stays_total_nights
# 0    City Hotel               79330
# 1  Resort Hotel               40060

# %%
bookings
# Out:
#                hotel  is_canceled  lead_time arrival_full_date  \
# 0       Resort Hotel            0        342        2015-07-01
# 1       Resort Hotel            0        737        2015-07-01
# 2       Resort Hotel            0          7        2015-07-01
# 3       Resort Hotel            0         13        2015-07-01
# 4       Resort Hotel            0         14        2015-07-01
# ...              ...          ...        ...               ...
# 119385    City Hotel            0         23        2017-08-30
# 119386    City Hotel            0        102        2017-08-31
# 119387    City Hotel            0         34        2017-08-31
# 119388    City Hotel            0        109        2017-08-31
# 119389    City Hotel            0        205        2017-08-29
#
#         arrival_date_year arrival_date_month  arrival_date_week_number  \
# 0                    2015               July                        27
# ...

# %%
a = bookings.groupby(['hotel'],as_index = False).agg({'stays_total_nights':'mean'})
print(a)
a['stays_total_nights'].round(2)
# Out:
#           hotel  stays_total_nights
# 0    City Hotel            2.978142
# 1  Resort Hotel            4.318547
# 0    2.98
# 1    4.32
# Name: stays_total_nights, dtype: float64

# %%
# Out:
# 0         0
# 1         0
# 2         1
# 3         1
# 4         2
#          ..
# 119385    7
# 119386    7
# 119387    7
# 119388    7
# 119389    9
# Name: stays_total_nights, Length: 119390, dtype: int64

# %%
bookings.query('assigned_room_type != reserved_room_type').count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-e2985e6b5483> in <module>
# ----> 1 bookings.query('assigned_room_type != reserved_room_type').count()
#
# NameError: name 'bookings' is not defined

# %%
bookings.query('hotel=="City Hotel" and is_canceled==1').groupby(['arrival_date_year', 'arrival_date_month']).is_canceled \
    .value_counts()
# Out:
# arrival_date_year  arrival_date_month  is_canceled
# 2015               August              1              1232
#                    December            1               668
#                    July                1               939
#                    November            1               301
#                    October             1              1321
#                    September           1              1543
# 2016               April               1              1539
#                    August              1              1247
#                    December            1              1072
#                    February            1               930
#                    January             1               438
#                    July                1              1043
#                    June                1              1720
#                    March               1              1108
#                    May                 1              1436
# ...

# %%
bookings.groupby('arrival_date_year'['arrival_date_month'])
# Out:
# <>:1: SyntaxWarning: str indices must be integers or slices, not str; perhaps you missed a comma?
# <>:1: SyntaxWarning: str indices must be integers or slices, not str; perhaps you missed a comma?
# <ipython-input-17-49968733b234>:1: SyntaxWarning: str indices must be integers or slices, not str; perhaps you missed a comma?
#   bookings.groupby('arrival_date_year'['arrival_date_month'])
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-49968733b234> in <module>
# ----> 1 bookings.groupby('arrival_date_year'['arrival_date_month'])
#
# TypeError: string indices must be integers

# %%
bookings.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
bookings
# Out:
#                hotel  is_canceled  lead_time arrival_full_date  \
# 0       Resort Hotel            0        342        2015-07-01
# 1       Resort Hotel            0        737        2015-07-01
# 2       Resort Hotel            0          7        2015-07-01
# 3       Resort Hotel            0         13        2015-07-01
# 4       Resort Hotel            0         14        2015-07-01
# ...              ...          ...        ...               ...
# 119385    City Hotel            0         23        2017-08-30
# 119386    City Hotel            0        102        2017-08-31
# 119387    City Hotel            0         34        2017-08-31
# 119388    City Hotel            0        109        2017-08-31
# 119389    City Hotel            0        205        2017-08-29
#
#         arrival_date_year arrival_date_month  arrival_date_week_number  \
# 0                    2015               July                        27
# ...

# %%
bookings['total_kids'] = bookings['children'] + bookings['babies']

# %%
bookings
# Out:
#                hotel  is_canceled  lead_time arrival_full_date  \
# 0       Resort Hotel            0        342        2015-07-01
# 1       Resort Hotel            0        737        2015-07-01
# 2       Resort Hotel            0          7        2015-07-01
# 3       Resort Hotel            0         13        2015-07-01
# 4       Resort Hotel            0         14        2015-07-01
# ...              ...          ...        ...               ...
# 119385    City Hotel            0         23        2017-08-30
# 119386    City Hotel            0        102        2017-08-31
# 119387    City Hotel            0         34        2017-08-31
# 119388    City Hotel            0        109        2017-08-31
# 119389    City Hotel            0        205        2017-08-29
#
#         arrival_date_year arrival_date_month  arrival_date_week_number  \
# 0                    2015               July                        27
# ...

# %%
q = bookings.groupby('hotel').agg({'total_kids':'mean'})
b = q.round()
# Out:
#               total_kids
# hotel
# City Hotel          0.10
# Resort Hotel        0.14

# %%
round(bookings.query('total_kids == 0.0 and is_canceled == 1').shape[0] /
      bookings.query('total_kids == 0.0').shape[0] * 100,2)
# Out:
# 37.22
